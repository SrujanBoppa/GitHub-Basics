# %% [markdown]
# <a href="https://colab.research.google.com/github/SrujanBoppa/GitHub-Basics/blob/main/PYTHON_BASICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
b=10
print(b)
print(id(b))
# Out:
# 10
# 11654664

# %%
a=10
print(a)
print(id(a))
# Out:
# 10
# 11654664

# %% [markdown]
# Data Types

# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
a=23.5
print(type(a))
# Out:
# <class 'float'>

# %%
a="srujan"
print(type(a))
# Out:
# <class 'str'>

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %% [markdown]
# Basic Math

# %%
a=9
b=10
print(a-b)
# Out:
# -1

# %%
print(b-a)
# Out:
# 1

# %%
print(a*b)#multiplication
# Out:
# 90

# %%
print(b/a),#divsion
print(b//a)#flooring
# Out:
# 1.1111111111111112
# 1

# %%
print(b%a)#remainder
# Out:
# 1

# %%
print(a**b)#exponential
# Out:
# 3486784401

# %%
a=-6
print(abs(a))
# Out:
# 6

# %% [markdown]
# Print Function& Parameters of Print

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("A","B","C",sep="")
# Out:
# ABC

# %%
print("My age is 26")
# Out:
# My age is 26

# %%
age=26
print("My age is",age)
# Out:
# My age is 26

# %%
print("My age is " + "26")
# Out:
# My age is 26

# %%
print("My name is sai\n")
print("My age is 26")
# Out:
# My name is sai
#
# My age is 26

# %%
variable=input()
print(variable)
# Out:
# sai
# sai

# %%
variable=input("enter your name : ")
print(variable)
# Out:
# enter your name : sai
# sai

# %%
variable=input("enter your name : ")
print(variable)
print(type(variable))
# Out:
# enter your name : srujan
# srujan
# <class 'str'>

# %% [markdown]
# Type Conversion

# %%
a="10"
print(type(a))
a=int(10)
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>

# %%
age=int(input("enter your age : "))
print(age)
print(type(age))
# Out:
# enter your age : 5
# 5
# <class 'int'>

# %% [markdown]
# FSTRING---Formatting

# %%
name="SAI"
print(f"my name is {name}")
# Out:
# my name is SAI
